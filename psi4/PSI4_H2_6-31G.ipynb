# %% [markdown]
# ### Psi4 UHF

# %%
import psi4
psi4.core.be_quiet()

# %%
psi4.set_memory('50000 MB')


molecule_geometry="""
H 0.0 0.0 0.0
H {0} 0.0 0.0
symmetry c1
"""
            

opt={'scf_type': 'pk',
     'basis': '6-31g',
     'reference' :{},
     #'freeze_core': True,
     'guess': 'huckel',
     'guess_mix' : True
                 }

# %%
R1=[0.3,0.4,0.5,0.6,0.7,0.8,0.9,1.0,1.2,1.4,1.6,1.8,2.0,2.2,2.4,2.6,2.8,3.0,4.0,5.0]
R2=[0.6,0.61,0.62,0.63,0.64,0.65,0.66,0.67,0.68,0.69,0.7,0.71,0.72,0.73,0.74,0.75,0.76,0.77,0.78,0.79,0.8]

# %%
opt['reference']='rhf'
fci=[]
rhf=[]
nuclear_repulsion_energy=[]
for i in range(len(R1)):
    r=R1[i]
    h2 = psi4.geometry(molecule_geometry.format(r))
    nuclear_repulsion_energy.append(h2.nuclear_repulsion_energy())
    mole_opt=psi4.set_options(opt)
    rhf.append(psi4.energy('scf'))
    fci.append(psi4.energy('fci'))

# %%
opt['reference']='uhf'
uhf=[]
for i in range(len(R1)):
    r=R1[i]
    h2 = psi4.geometry(molecule_geometry.format(r))
    mole_opt=psi4.set_options(opt)
    uhf.append(psi4.energy('scf'))

# %%
import pandas as pd
import numpy as np

dic = {
    "H-H Length": R1, 
    "RHF": rhf,
    "UHF": uhf,
    "Repulsion" :nuclear_repulsion_energy ,
    "FCI": fci,
    "FCI-Repulsion":np.array(fci)-np.array(nuclear_repulsion_energy)
}
df = pd.DataFrame(dic)
df
# Out:
#     H-H Length       RHF       UHF  Repulsion       FCI  FCI-Repulsion
# 0          0.3 -0.645155 -0.645155   1.763924 -0.660510      -2.424434
# 1          0.4 -0.933004 -0.933004   1.322943 -0.950679      -2.273622
# 2          0.5 -1.058025 -1.058025   1.058354 -1.077864      -2.136218
# 3          0.6 -1.110031 -1.110031   0.881962 -1.131953      -2.013915
# 4          0.7 -1.126123 -1.126123   0.755967 -1.150157      -1.906124
# 5          0.8 -1.123713 -1.123713   0.661472 -1.150028      -1.811499
# 6          0.9 -1.111686 -1.111686   0.587975 -1.140602      -1.728577
# 7          1.0 -1.094808 -1.094808   0.529177 -1.126778      -1.655956
# 8          1.2 -1.055759 -1.055784   0.440981 -1.095595      -1.536576
# 9          1.4 -1.016326 -1.027298   0.377984 -1.066775      -1.444759
# 10         1.6 -0.979470 -1.012584   0.330736 -1.043432      -1.374168
# 11         1.8 -0.946052 -1.004937   0.293987 -1.026136      -1.320123
# 12         2.0 -0.916271 -1.000935   0.264589 -1.014310      -1.278899
# 13         2.2 -0.890053 -0.998838   0.240535 -1.006794      -1.247329
# 14         2.4 -0.867175 -0.997741   0.220491 -1.002290      -1.222781
# 15         2.6 -0.847339 -0.997167   0.203530 -0.999703      -1.203233
# 16         2.8 -0.830241 -0.996866   0.188992 -0.998255      -1.187247
# 17         3.0 -0.815592 -0.996704   0.176392 -0.997455      -1.173847
# 18         4.0 -0.770203 -0.996485   0.132294 -0.996512      -1.128806
# 19         5.0 -0.751389 -0.996466   0.105835 -0.996467      -1.102302

# %%
opt['reference']='rhf'
fci=[]
rhf=[]
nuclear_repulsion_energy=[]
for i in range(len(R2)):
    r=R2[i]
    h2 = psi4.geometry(molecule_geometry.format(r))
    nuclear_repulsion_energy.append(h2.nuclear_repulsion_energy())
    mole_opt=psi4.set_options(opt)
    rhf.append(psi4.energy('scf'))
    fci.append(psi4.energy('fci'))

# %%
opt['reference']='uhf'
uhf=[]
for i in range(len(R2)):
    r=R2[i]
    h2 = psi4.geometry(molecule_geometry.format(r))
    mole_opt=psi4.set_options(opt)
    uhf.append(psi4.energy('scf'))

# %%
import pandas as pd
import numpy as np

dic = {
    "H-H Length": R2, 
    "RHF": rhf,
    "UHF": uhf,
    "Repulsion" :nuclear_repulsion_energy ,
    "FCI": fci,
    "FCI-Repulsion":np.array(fci)-np.array(nuclear_repulsion_energy)
}
df = pd.DataFrame(dic)
df
# Out:
#     H-H Length       RHF       UHF  Repulsion       FCI  FCI-Repulsion
# 0         0.60 -1.110031 -1.110031   0.881962 -1.131953      -2.013915
# 1         0.61 -1.112869 -1.112869   0.867504 -1.134999      -2.002503
# 2         0.62 -1.115384 -1.115384   0.853512 -1.137723      -1.991234
# 3         0.63 -1.117598 -1.117598   0.839964 -1.140145      -1.980109
# 4         0.64 -1.119530 -1.119530   0.826839 -1.142286      -1.969126
# 5         0.65 -1.121198 -1.121198   0.814119 -1.144164      -1.958283
# 6         0.66 -1.122618 -1.122618   0.801784 -1.145795      -1.947579
# 7         0.67 -1.123806 -1.123806   0.789817 -1.147196      -1.937013
# 8         0.68 -1.124778 -1.124778   0.778202 -1.148380      -1.926582
# 9         0.69 -1.125546 -1.125546   0.766923 -1.149363      -1.916287
# 10        0.70 -1.126123 -1.126123   0.755967 -1.150157      -1.906124
# 11        0.71 -1.126522 -1.126522   0.745320 -1.150774      -1.896094
# 12        0.72 -1.126753 -1.126753   0.734968 -1.151225      -1.886193
# 13        0.73 -1.126828 -1.126828   0.724900 -1.151521      -1.876421
# 14        0.74 -1.126755 -1.126755   0.715104 -1.151673      -1.866777
# 15        0.75 -1.126545 -1.126545   0.705570 -1.151689      -1.857258
# 16        0.76 -1.126206 -1.126206   0.696286 -1.151578      -1.847864
# 17        0.77 -1.125745 -1.125745   0.687243 -1.151349      -1.838592
# 18        0.78 -1.125172 -1.125172   0.678432 -1.151009      -1.829442
# 19        0.79 -1.124492 -1.124492   0.669845 -1.150567      -1.820411
# 20        0.80 -1.123713 -1.123713   0.661472 -1.150028      -1.811499
